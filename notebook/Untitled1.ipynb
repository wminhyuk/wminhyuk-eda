# %%
pip install wminhyuk-eda==0.4.0
# Out:
# /home/seominhyuk/code/wminhyuk-eda/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
wminhyuk-eda
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 wminhyuk-eda
#
# NameError: name 'wminhyuk' is not defined

# %%
w --help
